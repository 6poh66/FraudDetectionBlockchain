# %%
from google.colab import files

files.upload()
# !mkdir -p ~/.kaggle


# !cp kaggle.json ~/.kaggle/


# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets download -d ealaxi/paysim1

# !unzip paysim1.zip
# Out:
#      <input type="file" id="files-5bc53633-2bf2-40e6-946c-41ecb45f5222" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5bc53633-2bf2-40e6-946c-41ecb45f5222">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Dataset Load

# %%
import pandas as pd

#Load
file_path = 'PS_20174392719_1491204439457_log.csv'
df = pd.read_csv(file_path)

# Display Header
print("Original Data Shape:", df.shape)
df.head()
# Out:
# Original Data Shape: (6362620, 11)
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
# !git clone https://github.com/6poh66/FraudDetectionBlockchain.git
# Out:
# Cloning into 'FraudDetectionBlockchain'...
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# Copy the notebook from your Google Drive into the cloned repository folder
# !cp "/content/drive/My Drive/Colab Notebooks/Fraud Detection.ipynb" "/content/FraudDetectionBlockchain/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# cp: cannot create regular file '/content/6poh66/FraudDetectionBlockchain>/': No such file or directory

# %%
# %cd 6poh66/FraudDetectionBlockchain

# !git config --global user.name "<6poh66>"
# !git config --global user.email "<vivekc.230299@gmail.com>"

# !git add Fraud Detection.ipynb

# Commit
# !git commit -m "Data PreProcessing"
# !git push
# Out:
# [Errno 2] No such file or directory: '6poh66/FraudDetectionBlockchain'
# /content
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
